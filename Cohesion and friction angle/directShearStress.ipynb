# %% [markdown]
# ### Derive cohesion and friction angle from the Direct Shear Test
# In this notebook, we will derive the cohesion and friction angle by using least square method, in this case it actually is Linear Regression method that given from sklearn package.
#
# the equation that we will use is:
# $$\tau = c + \sigma \tan(\phi)$$
#
# where:
# - $\tau$ is the shear stress
# - $c$ is the cohesion
# - $\sigma$ is the normal stress
# - $\phi$ is the friction angle
#
# All the source code have refactored in utils.py file for better readability

# %%
from utils import C_PhiCalulator

# %% [markdown]
# #### Layer 1

# %%
C_PhiCalulator('./LayerDST/Layer1.csv')
# Out:
#     0.25    0.5   0.75
# 0  0.076  0.086  0.096
# 1  0.065  0.076  0.086
# 2  0.071  0.106  0.093
# 3  0.086  0.106  0.121
# 4  0.088  0.101  0.123
# Cohesion (c): 0.067
# Friction angle (φ): 2.732
# (0.06742857142857142, 0.047678125471167114)

# %% [markdown]
# ### Layer 4

# %%
c, phi = C_PhiCalulator('./LayerDST/Layer4.csv')
# Out:
#      0.5      1    1.5
# 0  0.327  0.549  0.781
# 1  0.338  0.630  0.811
# 2  0.327  0.569  0.776
# 3  0.330  0.443  0.788
# 4  0.332  0.554  0.791
# Cohesion (c): 0.083
# Friction angle (φ): 25.487
# 0.0828666666666667 0.4448344697056924

# %%
import gspread as gs

gc = gs.service_account(filename='pysheetAuth.json')

sheet = gc.open('Pysheet').sheet1

sheet.update('A1', [['C', 'Phi']])
sheet.update('A2', [[c, phi]])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22316\710158107.py:7: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet.update('A1', [['C', 'Phi']])
# C:\Users\PC\AppData\Local\Temp\ipykernel_22316\710158107.py:8: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet.update('A2', [[c, phi]])
# {'spreadsheetId': '1EJQ6bxKrjV1wtX10zaluWRY4p-DVIT_aBEapkxs3S4M',
#  'updatedRange': 'Sheet1!A2:B2',
#  'updatedRows': 1,
#  'updatedColumns': 2,
#  'updatedCells': 2}
